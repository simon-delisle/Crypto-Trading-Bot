# %%
# Raw Package
import numpy as np
import pandas as pd

#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Custom classes
from Data_Preprocessing.technical_indicators import technical_analysis
ta = technical_analysis()
print(ta)
# Out:
# Custom module <technical_indicators> imported
# ...

# %% [markdown]
# # Data

# %%
data = yf.download(tickers='ETH-USD', period = '1y', interval = '1d')
data['Date'] = data.index
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-11-04   387.603210   407.665649   377.827606   402.141998   402.141998
# 2020-11-05   402.142944   417.525940   397.245819   414.067352   414.067352
# 2020-11-06   414.066711   456.200623   412.982300   454.719299   454.719299
# 2020-11-07   454.722565   465.675476   428.456360   435.713135   435.713135
# 2020-11-08   435.718811   457.780457   433.153778   453.554779   453.554779
# ...                 ...          ...          ...          ...          ...
# 2021-10-30  4414.243652  4426.848633  4252.494141  4325.650391  4325.650391
# 2021-10-31  4322.744141  4394.449707  4179.016113  4288.074219  4288.074219
# 2021-11-01  4288.217285  4377.322266  4160.966797  4324.626953  4324.626953
# 2021-11-02  4322.500977  4599.948242  4288.686523  4584.798828  4584.798828
# ...

# %%
df_candlestick_patterns = ta.find_candlestick_patterns(data)
df_candlestick_patterns
df_candlestick_patterns['candlestick_score'] = df_candlestick_patterns.iloc[:, 8:-1].sum(axis=1)
df_candlestick_patterns.to_csv('candlestick_patterns_test.csv')

# %%
fig = ta.candlestick_chart(title='Ethereum Chart', 
                            time=data.Date, 
                            open=data.Open, 
                            high=data.High, 
                            low=data.Low, 
                            close=data.Close, 
                            volume=data.Volume, 
                            show_support=True, 
                            show_resistance=True,
                            show_local_mins=True, 
                            show_local_maxs=True,
                            weight_support_and_resistance=True,
                            weight_support_and_resistance_zones=200,
                            candlestick_score=df_candlestick_patterns['candlestick_score'].values
                        )
fig.show()
# Out:
# single positional indexer is out-of-bounds
